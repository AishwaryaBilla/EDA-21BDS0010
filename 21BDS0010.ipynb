# %% [markdown]
# WINTER SEMESTER 2024-25
#
# DIGITAL ASSESSMENT
#
# NAME: AISHWARYA BILLA
#
# REG NO.: 21BDS0010
#
# COURSE: EXPLORATORY DATA ANALYSIS
#
# COURSE CODE: BCSE331L

# %% [markdown]
# **MODULE 1**
#
# **NumPy and Pandas: Essential Data Operations and Transformations**
#
# Performed essential data operations, transformations, and statistical analyses to clean, manipulate, and extract insights from the dataset

# %%
import pandas as pd
import numpy as np

#1. Load the dataset
df = pd.read_csv("telco customer churn.csv")

# %%
#2. Display the first few rows
print("First 10 rows of the dataset:")
display(df.head(10))

#3. Basic Information about the dataset
print("\nDataset Information:")
df.info()
# Out:
# First 10 rows of the dataset:
#    customerID  gender  SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No      1           No
# 1  5575-GNVDE    Male            0.0      No         No     34          Yes
# 2  3668-QPYBK    Male            0.0      No         No      2          Yes
# 3  7795-CFOCW    Male            0.0      No         No     45           No
# 4  9237-HQITU  Female            0.0      No         No      2          Yes
# 5  9305-CDSKC  Female            0.0      No         No      8          Yes
# 6  1452-KIOVK    Male            0.0      No        Yes     22          Yes
# 7  6713-OKOMC  Female            0.0      No         No     10           No
# 8  7892-POOKP  Female            0.0     Yes         No     28          Yes
# 9  6388-TABGU    Male            0.0      No        Yes     62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
#4. Summary Statistics
print("\nSummary Statistics:")
display(df.describe())
# Out:
# Summary Statistics:
#        SeniorCitizen  MonthlyCharges
# count    7035.000000     7040.000000
# mean        0.162331       64.761889
# std         0.368781       30.087384
# min         0.000000       18.250000
# 25%         0.000000       35.500000
# 50%         0.000000       70.350000
# 75%         0.000000       89.850000
# max         1.000000      118.750000

# %%
#5. Checking for missing values
print("\nMissing values in each column:")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# customerID          0
# gender              0
# SeniorCitizen       8
# Partner             5
# Dependents          0
# tenure              1
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      3
# TotalCharges        0
# Churn               1
# dtype: int64

# %%
#6. Replacing empty strings or spaces in 'TotalCharges' with NaN and converting to float
df['TotalCharges'] = df['TotalCharges'].replace(" ", np.nan).astype(float)

#7. Filling missing TotalCharges with the median value
df.loc[:, 'TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

#8. Mapping categorical gender values to numerical values
df['gender'] = df['gender'].map({'Male': 1, 'Female': 0}).astype('Int64')  # Using nullable Int64 to allow NaNs

# %%
#9. Unique values in categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
print("\nUnique values in categorical columns:")
for col in categorical_cols:
    print(f"{col}: {df[col].unique()}")
# Out:
# Unique values in categorical columns:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# Partner: ['Yes' 'No' nan]
# Dependents: ['No' 'Yes' '?']
# tenure: ['1' '34' '2' '45' '8' '22' '10' '28' '62' '13' '16' '58' '49' '25' '69'
#  '52' '71' '21' '12' '30' '47' '72' '17' '27' '5' '46' '11' '70' '63' '43'
#  '15' '60' '18' '66' '9' '3' '31' '50' '64' '56' '7' '42' '35' '48' '29'
#  '65' '38' '68' '32' '55' '37' '36' '41' '6' '4' '33' '67' '23' '57' '61'
#  '14' '20' '53' '40' '59' '24' '44' '19' '54' '51' '26' '0' '39' nan '?']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service' '?']
# StreamingTV: ['No' 'Yes' 'No internet service']
# ...

# %%
#10. Basic Aggregation
print("\nAverage Monthly Charges by Churn status:")
display(df.groupby('Churn')['MonthlyCharges'].mean())
# Out:
# Average Monthly Charges by Churn status:
# Churn
# ?      88.125000
# No     61.261915
# Yes    74.439100
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# **MODULE 2**
#
# **Data Transformation**
#
# Performed data cleaning and transformation, including handling missing values, encoding categorical variables, and creating new calculated fields like merging datasets, binning numerical values, and filtering data

# %%
import pandas as pd
import numpy as np
import warnings


# 1. Load the dataset
df = pd.read_csv("telco customer churn.csv")

# 2. Display first 10 rows
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No      1           No
# 1  5575-GNVDE    Male            0.0      No         No     34          Yes
# 2  3668-QPYBK    Male            0.0      No         No      2          Yes
# 3  7795-CFOCW    Male            0.0      No         No     45           No
# 4  9237-HQITU  Female            0.0      No         No      2          Yes
# 5  9305-CDSKC  Female            0.0      No         No      8          Yes
# 6  1452-KIOVK    Male            0.0      No        Yes     22          Yes
# 7  6713-OKOMC  Female            0.0      No         No     10           No
# 8  7892-POOKP  Female            0.0     Yes         No     28          Yes
# 9  6388-TABGU    Male            0.0      No        Yes     62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
# Ensure MonthlyCharges and tenure are numeric
df['MonthlyCharges'] = pd.to_numeric(df['MonthlyCharges'], errors='coerce')  # Convert strings to float
df['tenure'] = pd.to_numeric(df['tenure'], errors='coerce')  # Convert strings to int

# 3. Add a new column calculating total charges
df['TotalCharges_Calculated'] = df['MonthlyCharges'] * df['tenure']

# 4. Count unique values in the 'Contract' column
df['Contract'].value_counts()

# 5. Summary statistics of numerical columns
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges_Calculated
# count    7035.000000  7041.000000     7040.000000              7038.000000
# mean        0.162331    32.373242       64.761889              2279.733696
# std         0.368781    24.562077       30.087384              2264.612632
# min         0.000000     0.000000       18.250000                 0.000000
# 25%         0.000000     9.000000       35.500000               394.187500
# 50%         0.000000    29.000000       70.350000              1393.700000
# 75%         0.000000    55.000000       89.850000              3786.650000
# max         1.000000    72.000000      118.750000              8550.000000

# %%
# 6. Data concatenation - Split dataset into two and combine again
df1 = df.iloc[:len(df)//2]
df2 = df.iloc[len(df)//2:]
df_combined = pd.concat([df1, df2], ignore_index=True)
df_combined.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# 7. Concatenate along columns
df_side_by_side = pd.concat([df1, df2], axis=1)
df_side_by_side.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...         NaN
# 1                No             DSL            Yes  ...         NaN
# 2                No             DSL            Yes  ...         NaN
# 3  No phone service             DSL            Yes  ...         NaN
# 4                No     Fiber optic             No  ...         NaN
#
#   StreamingTV StreamingMovies Contract PaperlessBilling PaymentMethod  \
# ...

# %%
# 8. Merge operation (inner join) - Assume 'Contract' is the key
df_merge_inner = df1.merge(df2, on='Contract', how='inner')
df_merge_inner.head()
# Out:
#   customerID_x gender_x  SeniorCitizen_x Partner_x Dependents_x  tenure_x  \
# 0   7590-VHVEG   Female              0.0       Yes           No       1.0
# 1   7590-VHVEG   Female              0.0       Yes           No       1.0
# 2   7590-VHVEG   Female              0.0       Yes           No       1.0
# 3   7590-VHVEG   Female              0.0       Yes           No       1.0
# 4   7590-VHVEG   Female              0.0       Yes           No       1.0
#
#   PhoneService_x   MultipleLines_x InternetService_x OnlineSecurity_x  ...  \
# 0             No  No phone service               DSL               No  ...
# 1             No  No phone service               DSL               No  ...
# 2             No  No phone service               DSL               No  ...
# 3             No  No phone service               DSL               No  ...
# 4             No  No phone service               DSL               No  ...
#
#     DeviceProtection_y        TechSupport_y        StreamingTV_y  \
# ...

# %%
# 9. Merge operation (left join)
df_merge_left = df1.merge(df2, on='Contract', how='left')
df_merge_left.head()
# Out:
#   customerID_x gender_x  SeniorCitizen_x Partner_x Dependents_x  tenure_x  \
# 0   7590-VHVEG   Female              0.0       Yes           No       1.0
# 1   7590-VHVEG   Female              0.0       Yes           No       1.0
# 2   7590-VHVEG   Female              0.0       Yes           No       1.0
# 3   7590-VHVEG   Female              0.0       Yes           No       1.0
# 4   7590-VHVEG   Female              0.0       Yes           No       1.0
#
#   PhoneService_x   MultipleLines_x InternetService_x OnlineSecurity_x  ...  \
# 0             No  No phone service               DSL               No  ...
# 1             No  No phone service               DSL               No  ...
# 2             No  No phone service               DSL               No  ...
# 3             No  No phone service               DSL               No  ...
# 4             No  No phone service               DSL               No  ...
#
#     DeviceProtection_y        TechSupport_y        StreamingTV_y  \
# ...

# %%
# 10. Merge operation (right join)
df_merge_right = df1.merge(df2, on='Contract', how='right')
df_merge_right.head()
# Out:
#   customerID_x gender_x  SeniorCitizen_x Partner_x Dependents_x  tenure_x  \
# 0   5575-GNVDE     Male              0.0        No           No      34.0
# 1   7795-CFOCW     Male              0.0        No           No      45.0
# 2   6388-TABGU     Male              0.0        No          Yes      62.0
# 3   8091-TTVAX     Male              0.0       Yes           No      58.0
# 4   8191-XWSZG   Female              NaN        No           No      52.0
#
#   PhoneService_x   MultipleLines_x InternetService_x     OnlineSecurity_x  \
# 0            Yes                No               DSL                  Yes
# 1             No  No phone service               DSL                  Yes
# 2            Yes                No               DSL                  Yes
# 3            Yes               Yes       Fiber optic                   No
# 4            Yes                No                No  No internet service
#
#    ... DeviceProtection_y TechSupport_y StreamingTV_y StreamingMovies_y  \
# ...

# %%
# 11. Reshaping using stack and unstack
reshaped_df = df[['MonthlyCharges', 'tenure', 'TotalCharges_Calculated']]
stacked = reshaped_df.stack()
stacked.unstack()
# Out:
#       MonthlyCharges  tenure  TotalCharges_Calculated
# 0              29.85     1.0                    29.85
# 1              56.95    34.0                  1936.30
# 2              53.85     2.0                   107.70
# 3              42.30    45.0                  1903.50
# 4              70.70     2.0                   141.40
# ...              ...     ...                      ...
# 7038           84.80    24.0                  2035.20
# 7039          103.20    72.0                  7430.40
# 7040           29.60    11.0                   325.60
# 7041           74.40     4.0                   297.60
# 7042          105.65    66.0                  6972.90
#
# [7043 rows x 3 columns]

# %%
# 12. Concatenating Series
df_series1 = pd.Series([100, 200, 300], index=['A', 'B', 'C'])
df_series2 = pd.Series([400, 500, 600], index=['D', 'E', 'F'])
df_combined_series = pd.concat([df_series1, df_series2], keys=['Group1', 'Group2'])
df_combined_series.unstack()
# Out:
#             A      B      C      D      E      F
# Group1  100.0  200.0  300.0    NaN    NaN    NaN
# Group2    NaN    NaN    NaN  400.0  500.0  600.0

# %%
# 13. Check for duplicate rows
df.duplicated().sum()

# 14. Remove duplicate rows
df_no_duplicates = df.drop_duplicates()
df_no_duplicates.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# 15. Replace values in dataframe
df_replace = df.copy()
warnings.simplefilter(action='ignore', category=FutureWarning)
df_replace.replace({'No': 0, 'Yes': 1}, inplace=True)
df_replace.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner Dependents  tenure  \
# 0  7590-VHVEG  Female            0.0      1.0          0     1.0
# 1  5575-GNVDE    Male            0.0      0.0          0    34.0
# 2  3668-QPYBK    Male            0.0      0.0          0     2.0
# 3  7795-CFOCW    Male            0.0      0.0          0    45.0
# 4  9237-HQITU  Female            0.0      0.0          0     2.0
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL              0  ...
# 1             1                 0             DSL              1  ...
# 2             1                 0             DSL              1  ...
# 3             0  No phone service             DSL              1  ...
# 4             1                 0     Fiber optic              0  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# 16. Check for missing values
df.isnull().sum()

# 17. Drop rows with NaN values
df_cleaned = df.dropna()
df_cleaned.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# 18. Fill missing values with 0
df_filled = df.fillna(0)
df_filled.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# 19. Forward fill missing values
df_ffill = df.fillna(method='ffill')
warnings.simplefilter(action='ignore', category=FutureWarning)
df_ffill.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# 20. Backward fill missing values
df_bfill = df.fillna(method='bfill')
warnings.simplefilter(action='ignore', category=FutureWarning)
df_bfill.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# 21. Categorize tenure into bins
bins = [0, 12, 24, 60, 100]
labels = ['Short-term', 'Mid-term', 'Long-term', 'Very Long-term']
df['Tenure_Category'] = pd.cut(df['tenure'], bins, labels=labels)
df['Tenure_Category'].value_counts()
# Out:
# Tenure_Category
# Long-term         2425
# Short-term        2175
# Very Long-term    1407
# Mid-term          1023
# Name: count, dtype: int64

# %%
# 22. Binning using qcut (quartiles)
df['Tenure_Quartile'] = pd.qcut(df['tenure'], 4)
df['Tenure_Quartile'].value_counts()
# Out:
# Tenure_Quartile
# (-0.001, 9.0]    1854
# (55.0, 72.0]     1755
# (29.0, 55.0]     1718
# (9.0, 29.0]      1714
# Name: count, dtype: int64

# %%
# 23. Filter transactions with high charges
df[df['TotalCharges_Calculated'] > 3000]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU    Male            0.0      No        Yes    62.0
# 12    8091-TTVAX    Male            0.0     Yes         No    58.0
# 13    0280-XJGEX    Male            0.0      No         No    49.0
# 15    3655-SNQYZ  Female            0.0     Yes        Yes    69.0
# 17    9959-WOFKT    Male            0.0      No        Yes    71.0
# ...          ...     ...            ...     ...        ...     ...
# 7028  9281-CEDRU  Female            0.0     Yes         No    68.0
# 7031  3605-JISKB    Male            1.0     Yes         No    55.0
# 7034  0639-TSIQW  Female            0.0      No         No    67.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 9             Yes            No             DSL            Yes  ...
# ...

# %%
# 24. Filter transactions with extremely high charges
df[df['TotalCharges_Calculated'] > 6000]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female            0.0     Yes        Yes    69.0
# 17    9959-WOFKT    Male            0.0      No        Yes    71.0
# 28    5248-YGIJN    Male            0.0     Yes         No    72.0
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 35    6234-RAAPL  Female            0.0     Yes        Yes    72.0
# ...          ...     ...            ...     ...        ...     ...
# 7022  7203-OYKCT    Male            0.0      No         No    72.0
# 7023  1035-IPQPU  Female            1.0     Yes         No    63.0
# 7034  0639-TSIQW  Female            0.0      No         No    67.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 15            Yes           Yes     Fiber optic            Yes  ...
# ...

# %%
# 25. Compute mean, sum, and cumulative sum for 'MonthlyCharges'
mean_charges = df['MonthlyCharges'].mean()
sum_charges = df['MonthlyCharges'].sum()
cumsum_charges = df['MonthlyCharges'].cumsum()

# 26. Display computed values
print(f"Mean Monthly Charges: {mean_charges}")
print(f"Total Monthly Charges: {sum_charges}")
print(f"Cumulative Monthly Charges:")
print(cumsum_charges.head())
# Out:
# Mean Monthly Charges: 64.76188920454545
# Total Monthly Charges: 455923.7
# Cumulative Monthly Charges:
# 0     29.85
# 1     86.80
# 2    140.65
# 3    182.95
# 4    253.65
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# **MODULE 3**
#
# **Correlation and analysis**
#
# Explores relationships between numerical variables using correlation coefficients and statistical tests. Various visualizations, including scatter plots, pair plots, and heatmaps, highlight patterns and dependencies. This analysis provides insights into key influencing factors and trends within the dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# 1. Load the dataset
df = pd.read_csv("telco customer churn.csv")

# 2. Display First and Last 3 rows of the dataset
print(df.head(3))
print(df.tail(3))
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No      1           No
# 1  5575-GNVDE    Male            0.0      No         No     34          Yes
# 2  3668-QPYBK    Male            0.0      No         No      2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
# 3. Check the data types of each column
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen       float64
# Partner              object
# Dependents           object
# tenure               object
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# 4. descriptive statistics
print(df.describe())
# Out:
#        SeniorCitizen  MonthlyCharges
# count    7035.000000     7040.000000
# mean        0.162331       64.761889
# std         0.368781       30.087384
# min         0.000000       18.250000
# 25%         0.000000       35.500000
# 50%         0.000000       70.350000
# 75%         0.000000       89.850000
# max         1.000000      118.750000

# %%
# 5. Check for missing values
print(pd.isna(df).sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       8
# Partner             5
# Dependents          0
# tenure              1
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      3
# TotalCharges        0
# Churn               1
# dtype: int64

# %%
# 6. Convert 'TotalCharges' to numeric, coercing errors to NaN
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# 7. Mean, Median, Mode
mean_val = df['TotalCharges'].mean()
median_val = df['TotalCharges'].median()
mode_val = df['TotalCharges'].mode()[0]

print(f"Mean: {mean_val}, Median: {median_val}, Mode: {mode_val}")

# 8. Compute standard deviation & variance
std_dev = df['TotalCharges'].std()
variance = df['TotalCharges'].var()

print(f"Standard Deviation: {std_dev}, Variance: {variance}")
# Out:
# Mean: 2283.3004408418656, Median: 1397.475, Mode: 20.2
# Standard Deviation: 2266.7713618831453, Variance: 5138252.40705357

# %%
# 9. Display the first 30 largest values of Customers by Internet Service Type column using bar chart
df['InternetService'].value_counts().nlargest(30).plot(kind='bar', figsize=(10,6))
plt.title("21BDS0010 - Number of Customers by Internet Service Type")
plt.ylabel("Count")
plt.xlabel("Internet Service Type")
plt.show()

# %%
# 10. Distribution plot
sns.histplot(df[col], kde=True)
plt.title(f"21BDS0010 - Distribution of {col}")
plt.show()

# %%
# 11. Boxplot for TotalCharges column
sns.boxplot(x=df[col])
plt.title(f"21BDS0010 - Boxplot of {col}")
plt.show()

# %%
# 12. Scatter plot between Monthly Charges and Total Charges columns
plt.scatter(df['MonthlyCharges'], df['TotalCharges'])
plt.title("21BDS0010 - Scatter Plot: Monthly Charges vs Total Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("Total Charges")
plt.show()

# %%
df_clean = df[['MonthlyCharges', 'TotalCharges']].dropna()

# 13. Compute correlation coefficient
corr_coeff = np.corrcoef(df_clean['MonthlyCharges'], df_clean['TotalCharges'])[0,1]
print(f"Correlation Coefficient between MonthlyCharges and TotalCharges: {corr_coeff}")
# Out:
# Correlation Coefficient between MonthlyCharges and TotalCharges: 0.6509871396085365

# %%
# 14. Boxplot between ContractType and TotalCharges column
sns.boxplot(x='Contract', y='TotalCharges', data=df)
plt.title("21BDS0010 - Boxplot: Contract Type vs Total Charges")
plt.show()

# %%
# Ensure 'MonthlyCharges', 'TotalCharges', and 'tenure' are numeric
df['MonthlyCharges'] = pd.to_numeric(df['MonthlyCharges'], errors='coerce')
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['tenure'] = pd.to_numeric(df['tenure'], errors='coerce')

# Drop any NaN values before plotting
df_clean = df.dropna(subset=['MonthlyCharges', 'TotalCharges', 'tenure'])

# 15. pairplot
sns.pairplot(df_clean, vars=['MonthlyCharges', 'TotalCharges', 'tenure'])
plt.show()

# %%
df.loc[:, 'TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())
df.loc[:, 'MonthlyCharges'] = df['MonthlyCharges'].fillna(df['MonthlyCharges'].median())


# 16. Compute Pearson correlation between MonthlyCHarges and totalCharges
pearson_corr = stats.pearsonr(df['MonthlyCharges'], df['TotalCharges'])
print(f"Pearson Correlation: {pearson_corr[0]}")
# Out:
# Pearson Correlation: 0.6505584925754195

# %%
# 17. Compute correlation matrix
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("21BDS0010 - Heatmap of Correlation Matrix")
plt.show()

# %% [markdown]
# **MODULE 4**
#
# **1D analysis**
#
# 1D (univariate) analysis examines a single variable independently to understand its distribution, central tendency (mean, median, mode), and spread. It includes statistical measures like skewness and kurtosis to assess shape and outliers. Common visualizations include histograms, box plots, and KDE plots to interpret patterns in the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# Step 1: Load the dataset
df = pd.read_csv("telco customer churn.csv")

# %%
# Step 2: Choose a numerical column for analysis
column = "MonthlyCharges"

# Step 3: Drop missing values for clean analysis
data = df[column].dropna()

# %%
# Step 4: Calculate statistical measures
mean_val = data.mean()
median_val = data.median()
mode_val = data.mode()[0]
skewness_val = skew(data)
kurtosis_val = kurtosis(data)

# %%
# Step 5: Print the calculated statistics
print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Mode: {mode_val:.2f}")
print(f"Skewness: {skewness_val:.2f}")
print(f"Kurtosis: {kurtosis_val:.2f}")
# Out:
# Mean: 64.76
# Median: 70.35
# Mode: 20.05
# Skewness: -0.22
# Kurtosis: -1.26

# %%
# Step 6: Plot histogram with KDE
plt.figure(figsize=(12, 5))
sns.histplot(data, kde=True, bins=30, color='blue', alpha=0.7)

# Step 7: Add vertical lines for mean, median, and mode
plt.axvline(mean_val, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mode_val, color='purple', linestyle='dashed', linewidth=2, label=f'Mode: {mode_val:.2f}')

plt.legend()
plt.title(f'21BDS0010- Distribution of {column} with Skewness and Kurtosis')
plt.xlabel(column)
plt.ylabel("Frequency")
plt.show()

# %%
# Step 8: Plot KDE separately
plt.figure(figsize=(12, 5))
sns.kdeplot(data, fill=True, color="blue")
plt.title(f"21BDS0010- Kurtosis Plot for {column}")
plt.xlabel(column)
plt.ylabel("Density")
plt.show()

# %%
# Step 9: Create a box plot to visualize the spread and outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x=data)
plt.title("21BDS0010- Box Plot")
plt.xlabel(column)
plt.show()

# %% [markdown]
# **MODULE 5**
#
# **K-Means clustering**
#
# K-Means is an unsupervised clustering algorithm that partitions data into K distinct clusters based on feature similarity. It iteratively assigns data points to the nearest cluster center and updates the centroids until convergence. The algorithm minimizes the intra-cluster variance using the Euclidean distance metric.

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# 1. Load dataset
df = pd.read_csv("telco customer churn.csv")

# %%
# 2. Select numerical features for clustering
X = df[['tenure', 'MonthlyCharges', 'TotalCharges']]

# 3. Convert columns to numeric, handling errors
X = X.apply(pd.to_numeric, errors='coerce')

# %%
# 4. Handle missing values (fill with column mean)
X = X.fillna(X.mean())

# 5. Standardize the numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 6. Apply K-Means clustering with k=2
kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# 7. Store cluster assignments in dataframe
df['Cluster'] = clusters

# %%
# 8. Convert required columns to numeric for plotting
df['tenure'] = pd.to_numeric(df['tenure'], errors='coerce')
df['MonthlyCharges'] = pd.to_numeric(df['MonthlyCharges'], errors='coerce')
df['Cluster'] = pd.to_numeric(df['Cluster'], errors='coerce')

# %%
# 9. Print cluster assignments for each customer
print("Cluster Assignments:")
print(df[['customerID', 'Cluster']])
# Out:
# Cluster Assignments:
#       customerID  Cluster
# 0     7590-VHVEG        0
# 1     5575-GNVDE        0
# 2     3668-QPYBK        0
# 3     7795-CFOCW        0
# 4     9237-HQITU        0
# ...          ...      ...
# 7038  6840-RESVB        0
# 7039  2234-XADUH        1
# 7040  4801-JZAZL        0
# 7041  8361-LTMKD        0
# 7042  3186-AJIEK        1
#
# [7043 rows x 2 columns]

# %%
# 10. Visualize clusters using a scatter plot
plt.figure(figsize=(16, 6))
scatter = plt.scatter(df['tenure'], df['MonthlyCharges'],
                      c=df['Cluster'], cmap='viridis')
plt.xlabel('Tenure')
plt.ylabel('Monthly Charges')
plt.title('21BDS0010- K-means Clustering (k=2)')
plt.colorbar(scatter, label='Cluster')

plt.show()

# %%
# 10. Visualize clusters using a scatter plot
plt.figure(figsize=(16, 6))
scatter = plt.scatter(df['tenure'], df['MonthlyCharges'],
                      c=df['Cluster'], cmap='viridis')
plt.xlabel('Tenure')
plt.ylabel('Monthly Charges')
plt.title('21BDS0010- K-means Clustering (k=2)')
plt.colorbar(scatter, label='Cluster')

# 11. Annotate customer IDs on the scatter plot
for i, txt in enumerate(df['customerID']):
    plt.annotate(txt, (df['tenure'][i], df['MonthlyCharges'][i]))

plt.show()

# %%
# 12. Create and display a hierarchical clustering dendrogram
plt.figure(figsize=(10, 6))
linked = linkage(X_scaled, method='ward')
dendrogram(linked,
           orientation='top',
           labels=df['customerID'].values,
           distance_sort='descending',
           show_leaf_counts=True)
plt.title('21BDS0010- Hierarchical Clustering Dendrogram')
plt.xlabel('Customer ID')
plt.ylabel('Distance')
plt.show()

# 13. Print cluster centers (scaled values)
print("\nCluster Centers (scaled):")
print(pd.DataFrame(kmeans.cluster_centers_,
                   columns=['tenure', 'MonthlyCharges', 'TotalCharges']))
# Out:
# Cluster Centers (scaled):
#      tenure  MonthlyCharges  TotalCharges
# 0 -0.500765       -0.417383     -0.621865
# 1  0.999400        0.832990      1.241085

# %%
# 14. Print statistical summary for each cluster
print("\nCluster Statistics:")
for cluster in range(2):
    print(f"\nCluster {cluster}:")
    print(df[df['Cluster'] == cluster][['tenure', 'MonthlyCharges', 'TotalCharges']].describe())
# Out:
# Cluster Statistics:
#
# Cluster 0:
#             tenure  MonthlyCharges
# count  4687.000000     4687.000000
# mean     20.057820       52.187764
# std      19.201469       27.201566
# min       0.000000       18.250000
# 25%       4.000000       21.100000
# 50%      14.000000       50.850000
# 75%      29.000000       75.600000
# max      72.000000      112.950000
#
# Cluster 1:
#             tenure  MonthlyCharges
# count  2354.000000     2353.000000
# mean     56.894223       89.808606
# std      12.927018       17.098013
# min      21.000000       38.500000
# 25%      47.000000       79.400000
# 50%      60.000000       92.950000
# 75%      69.000000      104.000000
# max      72.000000      118.750000

# %% [markdown]
# **MODULE 7**
#
# **Linear regression**
#
# Linear Regression is a supervised learning algorithm used to model the relationship between a dependent variable (target) and one or more independent variables (features) by fitting a straight line. It minimizes the difference between actual and predicted values using the least squares method. The model is evaluated using metrics like Mean Squared Error (MSE), Mean Absolute Error (MAE), and R² score.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# 1. Load the dataset
df = pd.read_csv("telco customer churn.csv")

# 2. Remove duplicate rows
df = df.drop_duplicates()

# %%
# 3. Handle missing values (fill with mean for numerical columns)
import warnings
warnings.simplefilter("ignore", category=FutureWarning)
for col in df.select_dtypes(include=['number']).columns:
    df[col].fillna(df[col].mean(), inplace=True)

# %%
# 4. Encode categorical variables using LabelEncoder
label_encoders = {}
for col in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# 5. Split dataset into features (X) and target (y)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# 6. Standardize feature values using StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 7. Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# 8. Train a Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 9. Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# 10. Evaluate model performance
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.4f}")
print(f"Mean Absolute Error: {mae:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Mean Squared Error: 0.1431
# Mean Absolute Error: 0.3103
# R² Score: 0.2689

# %%
# 11. Visualization of results
plt.figure(figsize=(12, 5))

# 12 Regression Plot - Actual vs Predicted values
plt.subplot(1, 2, 1)
sns.regplot(x=y_test, y=y_pred, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("21BDS0010- Actual vs Predicted")
# Out:
# Text(0.5, 1.0, '21BDS0010- Actual vs Predicted')

# %%
# 13 Residual Plot - Distribution of residuals
plt.subplot(1, 2, 2)
sns.histplot(y_test - y_pred, bins=20, kde=True, color="purple")
plt.xlabel("Residuals")
plt.title("21BDS0010- Residual Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Logistic regression**
#
# Logistic Regression is a supervised learning algorithm used for binary classification problems, predicting probabilities between two classes (e.g., Yes/No, 0/1). It applies the sigmoid function to map input features to a probability score and uses a decision threshold (typically 0.5) to classify outcomes. It is widely used in applications like customer churn prediction, disease diagnosis, and spam detection due to its simplicity and interpretability.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# 1. Load Data
df = pd.read_csv("telco customer churn.csv")

# %%
# 2. Handle Missing Values
df.replace(" ", np.nan, inplace=True)
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)

# %%
# 3. Encode Categorical Variables
label_encoders = {}
for col in ["gender", "Partner", "Dependents", "PhoneService", "MultipleLines",
            "InternetService", "OnlineSecurity", "OnlineBackup", "DeviceProtection",
            "TechSupport", "StreamingTV", "StreamingMovies", "Contract",
            "PaperlessBilling", "PaymentMethod", "Churn"]:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# 4. Select Features and Target Variable
features = ["tenure", "MonthlyCharges", "TotalCharges", "Contract", "InternetService",
            "OnlineSecurity", "PaymentMethod", "PaperlessBilling"]
X = df[features]
y = df["Churn"]

# %%
# 3. Handle missing values (fill with mean)
warnings.simplefilter("ignore", category=FutureWarning)
X.replace("?", np.nan, inplace=True)
X = X.apply(pd.to_numeric, errors='coerce')
X.fillna(X.mean(), inplace=True)

# 5. Scale Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 6. Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# 7. Train Logistic Regression Model
model = LogisticRegression()
model.fit(X_train, y_train)

# 8. Make Predictions
y_pred = model.predict(X_test)

# %%
# 9. Evaluate Model
warnings.filterwarnings("ignore")
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8006
#
# Confusion Matrix:
# [[  0   1   0]
#  [  0 922 113]
#  [  0 167 206]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.85      0.89      0.87      1035
#            2       0.65      0.55      0.60       373
#
#     accuracy                           0.80      1409
#    macro avg       0.50      0.48      0.49      1409
# weighted avg       0.79      0.80      0.80      1409

# %%
# 10. Visualization - Feature Importance
warnings.simplefilter("ignore", category=FutureWarning)
coefficients = pd.DataFrame({"Feature": features, "Importance": model.coef_[0]})
coefficients = coefficients.sort_values(by="Importance", ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x="Importance", y="Feature", data=coefficients, palette="viridis")
plt.title("21BDS0010- Feature Importance in Logistic Regression")
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.show()

# %%
# 11. Confusion Matrix Heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues", xticklabels=["No", "Yes"], yticklabels=["No", "Yes"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("21BDS0010- Confusion Matrix")
plt.show()
